# %%
import openai
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
client = openai.OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_API_BASE")
)

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": "Helo AI. What is Python in one sentence?"
        }
    ]
)

# %%
ai_text = response.choices[0].message.content # -> This is the golden path to AI answer after making the API call

print("\n" + "="*60)
print("Question: What is Python in one sentence?")
print("\nAI answer: ")
print(ai_text)
print("="*60)
# Out:
# ...
# Question: What is Python in one sentence?
#
# AI answer:
# Hello! I’m ChatGPT, an AI language model created by OpenAI. I’m here to help you with information, answer questions, assist with writing, brainstorming, and much more. How can I assist you today?
# ...

# %%
# Tokens count
input_tokens = response.usage.prompt_tokens
output_tokens = response.usage.completion_tokens
total_tokens = response.usage.total_tokens

print("Token Usage Report: ")
print("="*50)
print(f" Your question used: {input_tokens} tokens")
print(f" AI response used: {output_tokens} tokens")
print(f" Total tokens billed: {total_tokens} tokens")
# Out:
# Token Usage Report:
# ...
#  Your question used: 18 tokens
#  AI response used: 24 tokens
#  Total tokens billed: 42 tokens
